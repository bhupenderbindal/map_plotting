# %% [markdown]
# Goal: Use wikipedia to obtain the coordinates for the constituency in csv file and plot on the map.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ls2019_winner_data.csv')

# %% [markdown]
# As the wiki page for constituency has some sequence, the same is used to search for the wiki page and extract the coordinates. example: https://en.wikipedia.org/wiki/Srikakulam_Lok_Sabha_constituency

# %%
import requests
from bs4 import BeautifulSoup

coord_list = []
# List of place names
places = df['Constituency'].apply(lambda x: x.title())

# Loop through each place
for place in places:
    # Construct the Wikipedia URL for the place
    place = place + "_Lok_Sabha_constituency"
    place = place.replace(" ", "_")
    url = f"https://en.wikipedia.org/wiki/{place}"

    # Fetch the web page content
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    # Find the coordinates element using CSS selector
    coordinates_element = soup.find('span', class_='geo')
    # Extract coordinates if found
    if coordinates_element:
        coordinates = coordinates_element.get_text()
        coord_list.append(coordinates)
        print(f"{place}: Coordinates: {coordinates}")
    else:
        coord_list.append(None)
        print(f"{place}: Coordinates not found")
# Out:
# Alappuzha_Lok_Sabha_constituency: Coordinates: 9.51; 76.34
# Chitradurga_Lok_Sabha_constituency: Coordinates: 14.2; 76.4
# Nilgiris_Lok_Sabha_constituency: Coordinates: 11.5; 76.6
# Barpeta_Lok_Sabha_constituency: Coordinates: 26.32; 91.00
# Diamond_Harbour_Lok_Sabha_constituency: Coordinates: 22.1910091; 88.1904741
# Maldaha_Dakshin_Lok_Sabha_constituency: Coordinates: 24.8515889; 88.0109596
# Murshidabad_Lok_Sabha_constituency: Coordinates: 24.18; 88.27
# Kandhamal_Lok_Sabha_constituency: Coordinates: 20.177813; 84.173564
# Nellore_Lok_Sabha_constituency: Coordinates: 14.4; 80.0
# Baharampur_Lok_Sabha_constituency: Coordinates: 24.1; 88.25
# Attingal_Lok_Sabha_constituency: Coordinates: 8.6800; 76.8300
# Ghazipur_Lok_Sabha_constituency: Coordinates: 25.58; 83.58
# Tura_Lok_Sabha_constituency: Coordinates: 25.52; 90.19
# Nainital-Udhamsingh_Nagar_Lok_Sabha_constituency: Coordinates: 29.2; 79.52
# Kheri_Lok_Sabha_constituency: Coordinates: 27.92; 80.73
# Bhagalpur_Lok_Sabha_constituency: Coordinates: 25.2; 87.0
# Muzaffarpur_Lok_Sabha_constituency: Coordinates: 26.1; 85.4
# Gurdaspur_Lok_Sabha_constituency: Coordinates: 32.0; 75.4
# Almora_Lok_Sabha_constituency: Coordinates: 29.6; 79.6
# Azamgarh_Lok_Sabha_constituency: Coordinates: 26.06; 83.19
# Bahraich_Lok_Sabha_constituency: Coordinates: 27.58; 81.6
# Fatehgarh_Sahib_Lok_Sabha_constituency: Coordinates: 30.65; 76.39
# Gandhinagar_Lok_Sabha_constituency: Coordinates: 23.2; 72.6
# Shirur_Lok_Sabha_constituency: Coordinates: 18.8; 74.4
# Uttara_Kannada_Lok_Sabha_constituency: Coordinates: 14.7; 74.6
# Belgaum_Lok_Sabha_constituency: Coordinates: 15.9; 74.5
# Ujjain_Lok_Sabha_constituency: Coordinates: 23.2; 75.8
# Tiruvannamalai_Lok_Sabha_constituency: Coordinates: 12.2; 79.1
# Kodarma_Lok_Sabha_constituency: Coordinates: 24.467; 85.594
# Chikkodi_Lok_Sabha_constituency: Coordinates: 16.4; 74.6
# Pathanamthitta_Lok_Sabha_constituency: Coordinates: 9.3; 76.8
# Kendrapara_Lok_Sabha_constituency: Coordinates: 20.497667; 86.424726
# Malkajgiri_Lok_Sabha_constituency: Coordinates: 17.45; 78.53
# Mirzapur_Lok_Sabha_constituency: Coordinates: 25.14; 82.57
# Jhansi_Lok_Sabha_constituency: Coordinates: 25.45; 78.56
# Hamirpur_Lok_Sabha_constituency: Coordinates not found
# Bhubaneswar_Lok_Sabha_constituency: Coordinates: 20.325984; 85.819077
# Arambag_Lok_Sabha_constituency: Coordinates not found
# Khunti_Lok_Sabha_constituency: Coordinates: 23.07; 85.28
# Bikaner_Lok_Sabha_constituency: Coordinates: 28.0; 73.3
# Barrackpur_Lok_Sabha_constituency: Coordinates not found
# Udaipur_Lok_Sabha_constituency: Coordinates: 24.6; 73.7
# Shahjahanpur_Lok_Sabha_constituency: Coordinates: 27.88; 79.92
# Bilaspur_Lok_Sabha_constituency: Coordinates: 22.1; 82.1
# Rohtak_Lok_Sabha_constituency: Coordinates: 28.9; 76.6
# Mumbai_South_Lok_Sabha_constituency: Coordinates: 18.96; 72.83
# Hyderabad_Lok_Sabha_constituency: Coordinates: 17.4; 78.4
# Misrikh_Lok_Sabha_constituency: Coordinates: 27.43; 80.52
# Madhubani_Lok_Sabha_constituency: Coordinates: 26.3; 86.1
# Gadchiroli_Chimur_Lok_Sabha_constituency: Coordinates not found
# Buxar_Lok_Sabha_constituency: Coordinates: 25.6; 84.0
# Bolpur_Lok_Sabha_constituency: Coordinates: 23.67; 87.72
# Ghosi_Lok_Sabha_constituency: Coordinates: 26.12; 83.55
# Zahirabad_Lok_Sabha_constituency: Coordinates: 17.7; 77.6
# Chikkballapur_Lok_Sabha_constituency: Coordinates not found
# Shimoga_Lok_Sabha_constituency: Coordinates: 13.9; 75.6
# Sriperumbudur_Lok_Sabha_constituency: Coordinates: 13.0; 79.9
# Dhubri_Lok_Sabha_constituency: Coordinates: 26.0; 90.0
# Valmiki_Nagar_Lok_Sabha_constituency: Coordinates: 27.43; 83.91
# Machilipatnam_Lok_Sabha_constituency: Coordinates: 16.2; 81.1
# Tirupati_Lok_Sabha_constituency: Coordinates: 13.6; 79.4
# Karimnagar_Lok_Sabha_constituency: Coordinates: 18.4; 79.1
# Kolkata_Uttar_Lok_Sabha_constituency: Coordinates: 22.5726723; 88.3638815
# Adilabad_Lok_Sabha_constituency: Coordinates: 19.7; 78.5
# Kalahandi_Lok_Sabha_constituency: Coordinates: 19.871834; 83.102733
# Vizianagaram_Lok_Sabha_constituency: Coordinates: 18.1; 83.4
# Chalakudy_Lok_Sabha_constituency: Coordinates: 10.3; 76.3
# Ajmer_Lok_Sabha_constituency: Coordinates: 26.46; 74.62
# Sangrur_Lok_Sabha_constituency: Coordinates: 30.2; 75.8
# Bidar_Lok_Sabha_constituency: Coordinates: 17.91; 77.50
# Jalaun_Lok_Sabha_constituency: Coordinates: 26.06; 79.42
# Dindori_Lok_Sabha_constituency: Coordinates: 20.2; 73.8
# Cuttack_Lok_Sabha_constituency: Coordinates: 20.460691; 85.889718
# Yavatmal_Washim_Lok_Sabha_constituency: Coordinates not found
# Bulandshahr_Lok_Sabha_constituency: Coordinates: 28.4; 77.85
# Machhlishahr_Lok_Sabha_constituency: Coordinates: 25.69; 82.41
# Satara_Lok_Sabha_constituency: Coordinates: 17.7; 74.0
# Jamshedpur_Lok_Sabha_constituency: Coordinates: 22.80; 86.19
# Mayurbhanj_Lok_Sabha_constituency: Coordinates: 21.929411; 86.744454
# Kaiserganj_Lok_Sabha_constituency: Coordinates: 27.25; 81.55
# Hisar_Lok_Sabha_constituency: Coordinates: 29.2; 75.7
# Mizoram_Lok_Sabha_constituency: Coordinates: 23.36; 92.00
# Nawada_Lok_Sabha_constituency: Coordinates: 24.89; 85.54
# Jahanabad_Lok_Sabha_constituency: Coordinates: 25.2; 85.0
# Chittorgarh_Lok_Sabha_constituency: Coordinates: 24.9; 74.6
# Giridih_Lok_Sabha_constituency: Coordinates: 24.19; 86.30
# Berhampur_Lok_Sabha_constituency: Coordinates: 19.315316; 84.792338
# Keonjhar_Lok_Sabha_constituency: Coordinates: 21.641388; 85.612078
# Kheda_Lok_Sabha_constituency: Coordinates: 22.8; 72.7
# Kachchh_Lok_Sabha_constituency: Coordinates: 23.5; 70
# Dhar_Lok_Sabha_constituency: Coordinates: 22.598; 75.304
# Sasaram_Lok_Sabha_constituency: Coordinates: 25.0; 84.0
# Nanded_Lok_Sabha_constituency: Coordinates: 19.1; 77.3
# Namakkal_Lok_Sabha_constituency: Coordinates: 11.233; 78.167
# Amalapuram_Lok_Sabha_constituency: Coordinates: 16.6; 82.0
# Jamui_Lok_Sabha_constituency: Coordinates: 24.9; 86.2
# Khagaria_Lok_Sabha_constituency: Coordinates: 25.5; 86.5
# Mathurapur_Lok_Sabha_constituency: Coordinates: 22.1203; 88.3943
# Junagadh_Lok_Sabha_constituency: Coordinates: 21.5; 70.5
# Mahasamund_Lok_Sabha_constituency: Coordinates: 21.1; 82.1
# Jaipur_Rural_Lok_Sabha_constituency: Coordinates: 27.1; 75.6
# South_Goa_Lok_Sabha_constituency: Coordinates: 15.00; 74.05
# Bangalore_Rural_Lok_Sabha_constituency: Coordinates: 13.3; 77.6
# Vellore_Lok_Sabha_constituency: Coordinates: 12.920219; 79.133306
# Bangalore_North_Lok_Sabha_constituency: Coordinates: 13.14; 77.56
# Patan_Lok_Sabha_constituency: Coordinates: 23.9; 72.1
# Jalna_Lok_Sabha_constituency: Coordinates: 19.8; 75.9
# Warangal_Lok_Sabha_constituency: Coordinates: 18.0; 79.6
# Chennai_Central_Lok_Sabha_constituency: Coordinates: 13.036; 80.239
# Idukki_Lok_Sabha_constituency: Coordinates: 9.84; 76.90
# Raiganj_Lok_Sabha_constituency: Coordinates: 25.62; 88.12
# Ghatal_Lok_Sabha_constituency: Coordinates: 22.7; 87.7
# Bastar_Lok_Sabha_constituency: Coordinates: 19.2; 81.9
# Dadra_And_Nagar_Haveli_Lok_Sabha_constituency: Coordinates not found
# Jalore_Lok_Sabha_constituency: Coordinates: 25.3; 72.6
# Hatkanangle_Lok_Sabha_constituency: Coordinates: 16.7; 74.4
# Chandrapur_Lok_Sabha_constituency: Coordinates: 20.0; 79.3
# Tenkasi_Lok_Sabha_constituency: Coordinates: 9.0; 77.3
# Bhiwani_Mahendragarh_Lok_Sabha_constituency: Coordinates not found
# Nizamabad_Lok_Sabha_constituency: Coordinates: 18.7; 78.1
# Aonla_Lok_Sabha_constituency: Coordinates: 28.28; 79.16
# Tamluk_Lok_Sabha_constituency: Coordinates: 22.3; 87.9
# Supaul_Lok_Sabha_constituency: Coordinates: 26.1; 86.6
# Medinipur_Lok_Sabha_constituency: Coordinates: 22.4; 87.3
# Mainpuri_:_Bye_Election_On_05-12-2022_Lok_Sabha_constituency: Coordinates not found
# Madhepura_Lok_Sabha_constituency: Coordinates: 25.9; 86.8
# Rajsamand_Lok_Sabha_constituency: Coordinates: 25.1; 73.9
# Dharmapuri_Lok_Sabha_constituency: Coordinates: 12.1260; 78.154
# Inner_Manipur_Lok_Sabha_constituency: Coordinates: 24.60; 93.90
# Etawah_Lok_Sabha_constituency: Coordinates: 26.78; 79.02
# Kurnool_Lok_Sabha_constituency: Coordinates: 15.81; 78.04
# Gopalganj_Lok_Sabha_constituency: Coordinates: 26.5; 84.4
# Firozabad_Lok_Sabha_constituency: Coordinates: 27.15; 78.4
# Balaghat_Lok_Sabha_constituency: Coordinates: 21.800; 80.183
# Udhampur_Lok_Sabha_constituency: Coordinates: 32.9; 75.1
# Barasat_Lok_Sabha_constituency: Coordinates: 22.72; 88.48
# Chennai_North_Lok_Sabha_constituency: Coordinates: 13.160; 80.245
# Chandauli_Lok_Sabha_constituency: Coordinates: 25.15; 83.24
# Gautam_Buddha_Nagar_Lok_Sabha_constituency: Coordinates: 28.36; 77.55
# Kishanganj_Lok_Sabha_constituency: Coordinates: 26.1; 87.9
# Moradabad_Lok_Sabha_constituency: Coordinates: 28.83; 78.76
# Paschim_Champaran_Lok_Sabha_constituency: Coordinates: 27.2; 84.2
# Baghpat_Lok_Sabha_constituency: Coordinates: 28.94; 77.22
# Sambhal_Lok_Sabha_constituency: Coordinates: 28.59; 78.57
# Kalyan_Lok_Sabha_constituency: Coordinates: 19.2; 73.1
# Ahmedabad_West_Lok_Sabha_constituency: Coordinates: 23.03; 72.51
# Gulbarga_Lok_Sabha_constituency: Coordinates: 17.3; 76.8
# Krishnagiri_Lok_Sabha_constituency: Coordinates: 12.53; 78.23
# Anakapalle_Lok_Sabha_constituency: Coordinates not found
# Bhavnagar_Lok_Sabha_constituency: Coordinates: 21.8; 72.2
# Chevella_Lok_Sabha_constituency: Coordinates: 17.3; 78.1
# Valsad_Lok_Sabha_constituency: Coordinates: 20.6; 72.9
# Tiruvallur_Lok_Sabha_constituency: Coordinates: 13.1; 79.9
# Katihar_Lok_Sabha_constituency: Coordinates: 25.5; 87.6
# Betul_Lok_Sabha_constituency: Coordinates: 21.9; 77.9
# Jhalawar_Baran_Lok_Sabha_constituency: Coordinates not found
# Ponnani_Lok_Sabha_constituency: Coordinates: 10.8; 75.9
# Mandla_Lok_Sabha_constituency: Coordinates: 22.95; 81.2
# Srinagar_Lok_Sabha_constituency: Coordinates: 34.1; 74.8
# Pilibhit_Lok_Sabha_constituency: Coordinates: 28.63; 79.8
# Davanagere_Lok_Sabha_constituency: Coordinates: 14.45; 75.91
# Tumkur_Lok_Sabha_constituency: Coordinates: 13.3; 77.1
# Bagalkot_Lok_Sabha_constituency: Coordinates: 16.2; 75.7
# Mumbai_North_West_Lok_Sabha_constituency: Coordinates: 19.14; 72.86
# Jodhpur_Lok_Sabha_constituency: Coordinates: 26.3; 73.0
# Khargone_Lok_Sabha_constituency: Coordinates: 22.02; 74.91
# Satna_Lok_Sabha_constituency: Coordinates: 24.58; 80.83
# Erode_Lok_Sabha_constituency: Coordinates: 11.3; 77.7
# Secunderabad_Lok_Sabha_constituency: Coordinates: 17.44; 78.50
# Kaliabor_Lok_Sabha_constituency: Coordinates: 26.53; 93.09
# East_Delhi_Lok_Sabha_constituency: Coordinates: 28.6420; 77.2980
# Kallakurichi_Lok_Sabha_constituency: Coordinates: 11.7; 79.0
# Palghar_Lok_Sabha_constituency: Coordinates: 19.7; 72.8
# Singhbhum_Lok_Sabha_constituency: Coordinates: 22.47; 85.47
# Banka_Lok_Sabha_constituency: Coordinates: 24.9; 86.9
# Begusarai_Lok_Sabha_constituency: Coordinates: 25.4; 86.1
# Pune_Lok_Sabha_constituency: Coordinates: 18.5; 73.9
# Nagina_Lok_Sabha_constituency: Coordinates: 29.44; 78.43
# Tirunelveli_Lok_Sabha_constituency: Coordinates: 8.7; 77.7
# Araku_Lok_Sabha_constituency: Coordinates: 18.3333; 82.8667
# Raigarh_Lok_Sabha_constituency: Coordinates: 21.9; 83.4
# Mumbai_North_Lok_Sabha_constituency: Coordinates: 19.21; 72.85
# Darbhanga_Lok_Sabha_constituency: Coordinates: 26.2; 85.9
# Janjgir_Champa_Lok_Sabha_constituency: Coordinates not found
# Ratlam_Lok_Sabha_constituency: Coordinates: 23.33; 75.05
# Amritsar_Lok_Sabha_constituency: Coordinates: 31.66; 74.87
# Saharanpur_Lok_Sabha_constituency: Coordinates: 29.97; 77.55
# North_West_Delhi_Lok_Sabha_constituency: Coordinates: 28.7730; 77.0890
# Nagaur_Lok_Sabha_constituency: Coordinates: 27.2; 73.7
# Basti_Lok_Sabha_constituency: Coordinates: 26.79; 82.82
# Chandni_Chowk_Lok_Sabha_constituency: Coordinates: 28.6610; 77.2270
# Bathinda_Lok_Sabha_constituency: Coordinates: 30.2; 74.9
# Anantnag_Lok_Sabha_constituency: Coordinates: 33.73; 75.15
# Nandurbar_Lok_Sabha_constituency: Coordinates: 21.4; 74.2
# Mathura_Lok_Sabha_constituency: Coordinates: 27.48; 77.69
# Nashik_Lok_Sabha_constituency: Coordinates: 20.0; 73.8
# Ernakulam_Lok_Sabha_constituency: Coordinates: 9.99; 76.30
# Shahdol_Lok_Sabha_constituency: Coordinates: 23.3; 81.4
# Autonomous_District_Lok_Sabha_constituency: Coordinates: 26.19; 93.62
# Aurangabad_Lok_Sabha_constituency: Coordinates not found
# Sikkim_Lok_Sabha_constituency: Coordinates: 27.33; 88.62
# Parbhani_Lok_Sabha_constituency: Coordinates: 19.3; 76.8
# Ranaghat_Lok_Sabha_constituency: Coordinates: 23.18; 88.58
# Domariyaganj_Lok_Sabha_constituency: Coordinates: 27.2; 82.7
# Hardoi_Lok_Sabha_constituency: Coordinates: 27.39; 80.14
# Rewa_Lok_Sabha_constituency: Coordinates: 24.55; 81.29
# Maharajganj_Lok_Sabha_constituency: Coordinates not found
# Surat_Lok_Sabha_constituency: Coordinates: 21.2; 72.8
# Khadoor_Sahib_Lok_Sabha_constituency: Coordinates: 31.4; 75.1
# Dausa_Lok_Sabha_constituency: Coordinates: 26.9; 76.3
# Dahod_Lok_Sabha_constituency: Coordinates: 22.8; 74.3
# Guntur_Lok_Sabha_constituency: Coordinates: 16.3; 80.4
# Hazaribagh_Lok_Sabha_constituency: Coordinates: 23.99; 85.36
# Jalpaiguri_Lok_Sabha_constituency: Coordinates: 26.52; 88.73
# Bijapur_Lok_Sabha_constituency: Coordinates: 16.8; 75.7
# Alipurduars_Lok_Sabha_constituency: Coordinates: 26.50; 89.52
# Karur_Lok_Sabha_constituency: Coordinates: 10.95; 78.08
# Sundargarh_Lok_Sabha_constituency: Coordinates: 22.122872; 84.042673
# Jammu_Lok_Sabha_constituency: Coordinates: 32.7; 74.9
# Purulia_Lok_Sabha_constituency: Coordinates: 23.3; 86.4
# Korba_Lok_Sabha_constituency: Coordinates: 22.34; 82.76
# Pollachi_Lok_Sabha_constituency: Coordinates: 10.659; 77.008
# Kannur_Lok_Sabha_constituency: Coordinates: 11.87; 75.37
# Vadakara_Lok_Sabha_constituency: Coordinates not found
# Ramanathapuram_Lok_Sabha_constituency: Coordinates not found
# Amreli_Lok_Sabha_constituency: Coordinates: 21.6; 71.2
# Barmer_Lok_Sabha_constituency: Coordinates: 25.76; 71.40
# Sreerampur_Lok_Sabha_constituency: Coordinates not found
# Bansgaon_Lok_Sabha_constituency: Coordinates: 26.55; 83.35
# Banswara_Lok_Sabha_constituency: Coordinates: 23.55; 74.44
# Thoothukkudi_Lok_Sabha_constituency: Coordinates: 8.78; 78.1
# Narsapuram_Lok_Sabha_constituency: Coordinates not found
# Bhiwandi_Lok_Sabha_constituency: Coordinates: 19.3; 73.1
# Koppal_Lok_Sabha_constituency: Coordinates: 15.3; 76.1
# Sivaganga_Lok_Sabha_constituency: Coordinates: 9.8; 78.5
# Mohanlalganj_Lok_Sabha_constituency: Coordinates: 26.69; 80.98
# Nalanda_Lok_Sabha_constituency: Coordinates: 25.1; 85.5
# Siwan_Lok_Sabha_constituency: Coordinates: 26.2; 84.4
# Mahabubabad_Lok_Sabha_constituency: Coordinates: 17.6; 80.0
# Phulpur_Lok_Sabha_constituency: Coordinates: 25.55; 82.09
# Raver_Lok_Sabha_constituency: Coordinates: 21.2; 76.0
# Maldaha_Uttar_Lok_Sabha_constituency: Coordinates: 25.04; 88.14
# Jangipur_Lok_Sabha_constituency: Coordinates: 24.53; 88.07
# Arunachal_West_Lok_Sabha_constituency: Coordinates: 27.7; 93.4
# Chandigarh_Lok_Sabha_constituency: Coordinates: 30.7; 76.8
# Gonda_Lok_Sabha_constituency: Coordinates: 27.14; 81.96
# Kangra_Lok_Sabha_constituency: Coordinates: 32.1; 76.3
# Mavelikkara_Lok_Sabha_constituency: Coordinates not found
# Bhongir_Lok_Sabha_constituency: Coordinates: 17.5; 78.9
# Medak_Lok_Sabha_constituency: Coordinates: 18.0; 78.3
# Karimganj_Lok_Sabha_constituency: Coordinates: 24.9; 92.4
# Faridabad_Lok_Sabha_constituency: Coordinates: 28.404; 77.319
# Guna_Lok_Sabha_constituency: Coordinates: 24.65; 77.32
# Ramtek_Lok_Sabha_constituency: Coordinates: 21.4; 79.3
# Andaman_And_Nicobar_Islands_Lok_Sabha_constituency: Coordinates not found
# Jhargram_Lok_Sabha_constituency: Coordinates: 22.45; 87.00
# Rajkot_Lok_Sabha_constituency: Coordinates: 22.3; 70.8
# Malappuram_Lok_Sabha_constituency: Coordinates: 11.1; 76.1
# Amroha_Lok_Sabha_constituency: Coordinates: 28.9; 78.47
# Hamirpur_Lok_Sabha_constituency: Coordinates not found
# Hindupur_Lok_Sabha_constituency: Coordinates: 13.83; 77.49
# Faizabad_Lok_Sabha_constituency: Coordinates: 26.77; 82.15
# Narasaraopet_Lok_Sabha_constituency: Coordinates: 16.23; 80.05
# Hooghly_Lok_Sabha_constituency: Coordinates: 22.9; 88.4
# Outer_Manipur_Lok_Sabha_constituency: Coordinates: 25.15; 93.97
# Visakhapatnam_Lok_Sabha_constituency: Coordinates: 17.8; 83.2
# Kozhikode_Lok_Sabha_constituency: Coordinates: 11.27; 75.80
# Ongole_Lok_Sabha_constituency: Coordinates: 15.5; 80.0
# Karakat_Lok_Sabha_constituency: Coordinates: 25.2; 84.3
# Alwar_Lok_Sabha_constituency: Coordinates: 27.56; 76.62
# Dewas_Lok_Sabha_constituency: Coordinates: 23.0; 76.4
# Surendranagar_Lok_Sabha_constituency: Coordinates: 22.7; 71.6
# Dhenkanal_Lok_Sabha_constituency: Coordinates: 20.662499; 85.598593
# Krishnanagar_Lok_Sabha_constituency: Coordinates: 23.4; 88.5
# Tehri_Garhwal_Lok_Sabha_constituency: Coordinates: 30.4; 78.5
# Kolkata_Dakshin_Lok_Sabha_constituency: Coordinates: 22.5726723; 88.3638815
# Bijnor_Lok_Sabha_constituency: Coordinates: 29.38; 78.14
# Sultanpur_Lok_Sabha_constituency: Coordinates: 26.26; 82.07
# Virudhunagar_Lok_Sabha_constituency: Coordinates: 9.6; 78.0
# Anandpur_Sahib_Lok_Sabha_constituency: Coordinates: 31.24; 76.5
# Bhadrak_Lok_Sabha_constituency: Coordinates: 21.055805; 86.499699
# Mahbubnagar_Lok_Sabha_constituency: Coordinates not found
# Mumbai_North_East_Lok_Sabha_constituency: Coordinates: 19.13; 72.93
# Karauli_Dholpur_Lok_Sabha_constituency: Coordinates not found
# North_East_Delhi_Lok_Sabha_constituency: Coordinates: 28.7090; 77.2750
# Bharuch_Lok_Sabha_constituency: Coordinates: 21.7; 73.0
# Rajahmundry_Lok_Sabha_constituency: Coordinates: 17.01; 81.80
# New_Delhi_Lok_Sabha_constituency: Coordinates: 28.6350; 77.2200
# Jadavpur_Lok_Sabha_constituency: Coordinates: 22.502513; 88.3676051
# Anand_Lok_Sabha_constituency: Coordinates: 22.6; 72.9
# Baramulla_Lok_Sabha_constituency: Coordinates: 34.202; 74.352
# Rampur_Lok_Sabha_constituency: Coordinates: 25.47; 82.58
# Faridkot_Lok_Sabha_constituency: Coordinates: 30.68; 74.75
# Lakshadweep_Lok_Sabha_constituency: Coordinates: 10.57; 72.63
# Kanker_Lok_Sabha_constituency: Coordinates: 20.3; 81.5
# Farrukhabad_Lok_Sabha_constituency: Coordinates: 27.41; 79.48
# Mainpuri_Lok_Sabha_constituency: Coordinates: 27.22; 79.03
# Chittoor_Lok_Sabha_constituency: Coordinates: 13.15000; 78.97000
# Kokrajhar_Lok_Sabha_constituency: Coordinates: 26.4; 90.3
# Chhindwara_Lok_Sabha_constituency: Coordinates: 22.07; 78.93
# Nalgonda_Lok_Sabha_constituency: Coordinates: 17.1; 79.3
# Dakshina_Kannada_Lok_Sabha_constituency: Coordinates: 12.83; 75.24
# Khammam_Lok_Sabha_constituency: Coordinates: 17.2; 80.1
# Khandwa_Lok_Sabha_constituency: Coordinates: 21.3; 76.2
# Jhunjhunu_Lok_Sabha_constituency: Coordinates: 28.1; 75.4
# Varanasi_Lok_Sabha_constituency: Coordinates: 25.32; 82.99
# Morena_Lok_Sabha_constituency: Coordinates: 26.5; 78.0
# Amravati_Lok_Sabha_constituency: Coordinates: 20.9319417; 77.7652917
# Kurukshetra_Lok_Sabha_constituency: Coordinates: 30.0; 76.9
# Ganganagar_Lok_Sabha_constituency: Coordinates: 29.9; 73.9
# Godda_Lok_Sabha_constituency: Coordinates: 24.83; 87.21
# Sambalpur_Lok_Sabha_constituency: Coordinates: 21.48; 83.98
# Nagpur_Lok_Sabha_constituency: Coordinates: 21.1; 79.1
# Ujiarpur_Lok_Sabha_constituency: Coordinates: 25.8; 85.8
# Basirhat_Lok_Sabha_constituency: Coordinates: 22.66; 88.89
# Kota_Lok_Sabha_constituency: Coordinates: 25.2; 75.9
# Osmanabad_Lok_Sabha_constituency: Coordinates: 18.2; 76.0
# Coimbatore_Lok_Sabha_constituency: Coordinates: 11.0; 77.0
# Bangalore_Central_Lok_Sabha_constituency: Coordinates: 12.99; 77.61
# Pali_Lok_Sabha_constituency: Coordinates: 25.8; 73.3
# Theni_Lok_Sabha_constituency: Coordinates: 10.01; 77.48
# Rajampet_Lok_Sabha_constituency: Coordinates: 17.1; 81.7
# Perambalur_Lok_Sabha_constituency: Coordinates: 11.23; 78.88
# Robertsganj_Lok_Sabha_constituency: Coordinates: 24.68; 83.08
# Thanjavur_Lok_Sabha_constituency: Coordinates: 10.8; 79.1
# Tezpur_Lok_Sabha_constituency: Coordinates: 26.7; 92.8
# Maharajganj_Lok_Sabha_constituency: Coordinates not found
# Banaskantha_Lok_Sabha_constituency: Coordinates: 24.3; 72.4
# Bardoli_Lok_Sabha_constituency: Coordinates: 21.11667; 73.1167
# Salem_Lok_Sabha_constituency: Coordinates: 11.67; 78.15
# West_Delhi_Lok_Sabha_constituency: Coordinates: 28.6660; 77.0670
# Hajipur_Lok_Sabha_constituency: Coordinates: 25.7; 85.2
# Dhanbad_Lok_Sabha_constituency: Coordinates: 23.81; 86.44
# Ahmedabad_East_Lok_Sabha_constituency: Coordinates: 23.019; 72.65
# Daman_And_Diu_Lok_Sabha_constituency: Coordinates not found
# Navsari_Lok_Sabha_constituency: Coordinates: 20.9; 72.9
# Hingoli_Lok_Sabha_constituency: Coordinates: 19.72; 77.15
# Puri_Lok_Sabha_constituency: Coordinates: 19.8; 85.8
# Nandyal_Lok_Sabha_constituency: Coordinates: 15.5; 78.5
# Mumbai_North_Central_Lok_Sabha_constituency: Coordinates: 19.2; 72.8
# Jamnagar_Lok_Sabha_constituency: Coordinates: 22.5; 70.0
# Nagarkurnool_Lok_Sabha_constituency: Coordinates: 16.5; 78.3
# Lakhimpur_Lok_Sabha_constituency: Coordinates: 26.5; 91.9
# Kairana_Lok_Sabha_constituency: Coordinates: 29.4; 77.2
# Araria_Lok_Sabha_constituency: Coordinates: 26.1; 87.4
# Nawgong_Lok_Sabha_constituency: Coordinates not found
# Damoh_Lok_Sabha_constituency: Coordinates: 23.82; 79.44
# Hassan_Lok_Sabha_constituency: Coordinates: 13.0; 76.1
# Dharwad_Lok_Sabha_constituency: Coordinates: 15.5; 75.0
# Aska_Lok_Sabha_constituency: Coordinates: 19.620277; 84.664078
# Howrah_Lok_Sabha_constituency: Coordinates: 22.5736296; 88.3251045
# Balasore_Lok_Sabha_constituency: Coordinates: 21.489723; 86.920189
# Buldhana_Lok_Sabha_constituency: Coordinates: 20.5; 76.2
# Mysore_Lok_Sabha_constituency: Coordinates: 12.3; 76.6
# Tripura_West_Lok_Sabha_constituency: Coordinates: 23.85; 91.28
# Jaynagar_Lok_Sabha_constituency: Coordinates: 22.1751965; 88.4200762
# Sant_Kabir_Nagar_Lok_Sabha_constituency: Coordinates: 26.73; 83.02
# Kollam_Lok_Sabha_constituency: Coordinates: 8.89; 76.61
# Patiala_Lok_Sabha_constituency: Coordinates: 30.3; 76.4
# Beed_Lok_Sabha_constituency: Coordinates: 18.9863306; 75.7671833
# Gauhati_Lok_Sabha_constituency: Coordinates: 26.2; 91.7
# Arrah_Lok_Sabha_constituency: Coordinates: 25.6; 84.7
# Banda_Lok_Sabha_constituency: Coordinates: 25.48; 80.34
# Purvi_Champaran_Lok_Sabha_constituency: Coordinates: 26.6; 84.9
# Wayanad_Lok_Sabha_constituency: Coordinates: 11.634; 75.992
# Churu_Lok_Sabha_constituency: Coordinates: 28.3; 75.0
# Mumbai_South_Central_Lok_Sabha_constituency: Coordinates: 19.0; 72.9
# Raichur_Lok_Sabha_constituency: Coordinates: 16.2; 77.4
# Thane_Lok_Sabha_constituency: Coordinates: 19.22; 72.98
# Jagatsinghpur_Lok_Sabha_constituency: Coordinates: 20.210605; 86.168113
# Sagar_Lok_Sabha_constituency: Coordinates: 23.83; 78.71
# Silchar_Lok_Sabha_constituency: Coordinates: 24.8; 92.8
# Meerut_Lok_Sabha_constituency: Coordinates: 28.98; 77.71
# Sitapur_Lok_Sabha_constituency: Coordinates: 27.51; 80.76
# Saran_Lok_Sabha_constituency: Coordinates: 25.9; 84.8
# Munger_Lok_Sabha_constituency: Coordinates: 25.4; 86.5
# Fatehpur_Sikri_Lok_Sabha_constituency: Coordinates: 27.1; 77.67
# Kasaragod_Lok_Sabha_constituency: Coordinates: 12.51; 74.98
# Lucknow_Lok_Sabha_constituency: Coordinates: 26.85; 80.94
# Darjeeling_Lok_Sabha_constituency: Coordinates: 27.039; 88.264
# Etah_Lok_Sabha_constituency: Coordinates: 27.56; 78.66
# Hathras_Lok_Sabha_constituency: Coordinates: 27.6; 78.05
# Jabalpur_Lok_Sabha_constituency: Coordinates: 23.16; 79.95
# Jaipur_Lok_Sabha_constituency: Coordinates: 26.90; 75.79
# Pataliputra_Lok_Sabha_constituency: Coordinates: 25.6; 85.1
# Shrawasti_Lok_Sabha_constituency: Coordinates not found
# Mandi_Lok_Sabha_constituency: Coordinates: 31.7; 76.9
# Sheohar_Lok_Sabha_constituency: Coordinates: 26.5; 85.29
# Vidisha_Lok_Sabha_constituency: Coordinates: 23.53; 77.82
# Mayiladuthurai_Lok_Sabha_constituency: Coordinates: 11.1018845; 79.5795889
# Deoria_Lok_Sabha_constituency: Coordinates: 26.5; 83.78
# Samastipur_Lok_Sabha_constituency: Coordinates: 25.9; 85.8
# Wardha_Lok_Sabha_constituency: Coordinates: 20.7; 78.6
# South_Delhi_Lok_Sabha_constituency: Coordinates: 28.5040; 77.2140
# Bhadohi_Lok_Sabha_constituency: Coordinates: 25.39; 82.57
# Sonipat_Lok_Sabha_constituency: Coordinates: 29.0; 77.1
# Nabarangpur_Lok_Sabha_constituency: Coordinates: 19.23; 82.55
# Haridwar_Lok_Sabha_constituency: Coordinates: 29.9; 78.1
# Porbandar_Lok_Sabha_constituency: Coordinates: 21.6; 69.6
# Dibrugarh_Lok_Sabha_constituency: Coordinates: 27.5; 94.9
# Srikakulam_Lok_Sabha_constituency: Coordinates: 18.3; 83.9
# Jhanjharpur_Lok_Sabha_constituency: Coordinates: 26.2667; 86.2833
# Alathur_Lok_Sabha_constituency: Coordinates: 10.6; 76.5
# Vadodara_Lok_Sabha_constituency: Coordinates: 22.18; 73.12
# Bharatpur_Lok_Sabha_constituency: Coordinates: 27.22; 77.49
# Madha_Lok_Sabha_constituency: Coordinates: 18.0; 75.5
# Gurgaon_Lok_Sabha_constituency: Coordinates: 28.4; 77.0
# Hoshangabad_Lok_Sabha_constituency: Coordinates: 22.667; 77.500
# Panchmahal_Lok_Sabha_constituency: Coordinates: 22.7; 73.6
# Sabarkantha_Lok_Sabha_constituency: Coordinates: 23.8; 73.0
# Chhota_Udaipur_Lok_Sabha_constituency: Coordinates: 22.3; 74.0
# Ambala_Lok_Sabha_constituency: Coordinates: 30.377; 76.775
# Patna_Sahib_Lok_Sabha_constituency: Coordinates: 25.596; 85.230
# Viluppuram_Lok_Sabha_constituency: Coordinates: 11.94; 79.49
# Salempur_Lok_Sabha_constituency: Coordinates: 26.3; 83.92
# Gorakhpur_Lok_Sabha_constituency: Coordinates: 26.76; 83.39
# Ludhiana_Lok_Sabha_constituency: Coordinates: 30.9; 75.9
# Tripura_East_Lok_Sabha_constituency: Coordinates: 24.04; 92.02
# Dhaurahra_Lok_Sabha_constituency: Coordinates: 27.36; 81.04
# Surguja_Lok_Sabha_constituency: Coordinates not found
# Allahabad_Lok_Sabha_constituency: Coordinates: 25.4; 81.8
# Ambedkar_Nagar_Lok_Sabha_constituency: Coordinates: 25.41; 81.86
# Sidhi_Lok_Sabha_constituency: Coordinates: 24.42; 81.88
# Rajgarh_Lok_Sabha_constituency: Coordinates: 24.250; 74.933
# Arakkonam_Lok_Sabha_constituency: Coordinates: 13.1; 79.7
# Kolar_Lok_Sabha_constituency: Coordinates: 13.1; 78.1
# Shirdi_Lok_Sabha_constituency: Coordinates: 19.8; 74.5
# Fatehpur_Lok_Sabha_constituency: Coordinates: 25.92; 80.81
# Bhopal_Lok_Sabha_constituency: Coordinates: 23.2667; 77.4
# Uluberia_Lok_Sabha_constituency: Coordinates: 22.47; 88.11
# Bhind_Lok_Sabha_constituency: Coordinates: 26.6; 78.8
# Pratapgarh_Lok_Sabha_constituency: Coordinates: 25.89; 91.94
# Lalganj_Lok_Sabha_constituency: Coordinates: 26.16; 80.97
# Badaun_Lok_Sabha_constituency: Coordinates: 28.03; 79.13
# Karnal_Lok_Sabha_constituency: Coordinates: 29.7; 77.0
# Kolhapur_Lok_Sabha_constituency: Coordinates: 16.7; 74.2
# Ranchi_Lok_Sabha_constituency: Coordinates: 23.4; 85.3
# Akola_Lok_Sabha_constituency: Coordinates: 20.7089139; 76.9965917
# Sangli_Lok_Sabha_constituency: Coordinates: 16.8; 74.6
# Muzaffarnagar_Lok_Sabha_constituency: Coordinates: 29.5; 77.71
# Jalandhar_Lok_Sabha_constituency: Coordinates: 31.3; 75.6
# Purnia_Lok_Sabha_constituency: Coordinates: 25.8; 87.5
# Bareilly_Lok_Sabha_constituency: Coordinates: 28.37; 79.42
# Rajnandgaon_Lok_Sabha_constituency: Coordinates: 21.1; 81.0
# Koraput_Lok_Sabha_constituency: Coordinates: 18.814545; 82.708125
# Jajpur_Lok_Sabha_constituency: Coordinates: 20.831457; 86.328803
# Birbhum_Lok_Sabha_constituency: Coordinates: 23.9167; 87.5333
# Aligarh_Lok_Sabha_constituency: Coordinates: 27.9; 78.08
# Kanpur_Lok_Sabha_constituency: Coordinates: 26.46; 80.32
# Agra_Lok_Sabha_constituency: Coordinates: 27.18; 78.01
# Bishnupur_Lok_Sabha_constituency: Coordinates: 23.08; 87.32
# Kancheepuram_Lok_Sabha_constituency: Coordinates: 12.82; 79.71
# Nagapattinam_Lok_Sabha_constituency: Coordinates: 10.77; 79.83
# Indore_Lok_Sabha_constituency: Coordinates: 22.75; 75.83
# Bangaon_Lok_Sabha_constituency: Coordinates: 23.07; 88.82
# Mahesana_Lok_Sabha_constituency: Coordinates: 23.6; 72.4
# Thiruvananthapuram_Lok_Sabha_constituency: Coordinates: 8.5; 76.9
# Udupi_Chikmagalur_Lok_Sabha_constituency: Coordinates: 13.4; 75.2
# Mangaldoi_Lok_Sabha_constituency: Coordinates: 26.5; 92.0
# Solapur_Lok_Sabha_constituency: Coordinates: 17.66; 75.92
# North_Goa_Lok_Sabha_constituency: Coordinates: 15.67; 73.81
# Maval_Lok_Sabha_constituency: Coordinates: 18.8; 73.4
# Jaunpur_Lok_Sabha_constituency: Coordinates: 25.74; 82.67
# Kanthi_Lok_Sabha_constituency: Coordinates: 21.78; 87.74
# Amethi_Lok_Sabha_constituency: Coordinates: 26.16; 81.81
# Bolangir_Lok_Sabha_constituency: Coordinates: 20.681917; 83.338233
# Hoshiarpur_Lok_Sabha_constituency: Coordinates: 31.5; 75.9
# Rae_Bareli_Lok_Sabha_constituency: Coordinates: 26.23; 81.25
# Dum_Dum_Lok_Sabha_constituency: Coordinates: 22.62; 88.42
# Cooch_Behar_Lok_Sabha_constituency: Coordinates: 26.32419; 89.45103
# Eluru_Lok_Sabha_constituency: Coordinates: 16.7; 81.1
# Vijayawada_Lok_Sabha_constituency: Coordinates: 16.5; 80.6
# Tiruppur_Lok_Sabha_constituency: Coordinates: 11.1; 77.4
# Bankura_Lok_Sabha_constituency: Coordinates: 23.25; 87.07
# Bhilwara_Lok_Sabha_constituency: Coordinates: 25.3; 74.6
# Dhule_Lok_Sabha_constituency: Coordinates: 20.9; 74.8
# Kannauj_Lok_Sabha_constituency: Coordinates: 27.05; 79.92
# Lohardaga_Lok_Sabha_constituency: Coordinates: 23.4; 84.7
# Latur_Lok_Sabha_constituency: Coordinates: 18.4; 76.6
# Mandsour_Lok_Sabha_constituency: Coordinates: 24.07; 75.06
# Ahmednagar_Lok_Sabha_constituency: Coordinates: 19.1023500; 74.7502333
# Balurghat_Lok_Sabha_constituency: Coordinates: 25.22; 88.77
# Firozpur_Lok_Sabha_constituency: Coordinates: 30.94; 74.61
# Tonk_Sawai_Madhopur_Lok_Sabha_constituency: Coordinates not found
# Mandya_Lok_Sabha_constituency: Coordinates: 12.5; 76.9
# Chennai_South_Lok_Sabha_constituency: Coordinates: 12.87; 80.19
# Sikar_Lok_Sabha_constituency: Coordinates: 27.6; 75.2
# Bhandara_Gondiya_Lok_Sabha_constituency: Coordinates not found
# Sitamarhi_Lok_Sabha_constituency: Coordinates: 26.6; 85.5
# Bardhaman_Purba_Lok_Sabha_constituency: Coordinates: 23.2; 87.9
# Chatra_Lok_Sabha_constituency: Coordinates: 24.21; 84.87
# Raipur_Lok_Sabha_constituency: Coordinates: 21.3; 81.6
# Dumka_Lok_Sabha_constituency: Coordinates: 24.3; 87.3
# Sirsa_Lok_Sabha_constituency: Coordinates: 29.5; 75.0
# Baramati_Lok_Sabha_constituency: Coordinates: 18.1562917; 74.5802889
# Bardhaman_Durgapur_Lok_Sabha_constituency: Coordinates not found
# Bapatla_Lok_Sabha_constituency: Coordinates: 15.9; 80.5
# Shimla_Lok_Sabha_constituency: Coordinates: 31.1; 77.2
# Bargarh_Lok_Sabha_constituency: Coordinates: 21.347144; 83.628632
# Aurangabad_Lok_Sabha_constituency: Coordinates not found
# Unnao_Lok_Sabha_constituency: Coordinates: 26.59; 80.52
# Thrissur_Lok_Sabha_constituency: Coordinates: 10.5; 76.2
# Cuddalore_Lok_Sabha_constituency: Coordinates: 11.75; 79.75
# Anantapur_Lok_Sabha_constituency: Coordinates: 14.68; 77.6
# Arunachal_East_Lok_Sabha_constituency: Coordinates: 28.3; 96.3
# Raigad_Lok_Sabha_constituency: Coordinates: 18.2; 73.4
# Bangalore_South_Lok_Sabha_constituency: Coordinates: 12.76; 77.60
# Chidambaram_Lok_Sabha_constituency: Coordinates: 11.4; 79.7
# Tiruchirappalli_Lok_Sabha_constituency: Coordinates: 10.8; 78.7
# Kottayam_Lok_Sabha_constituency: Coordinates: 9.60; 76.52
# Garhwal_Lok_Sabha_constituency: Coordinates: 29.9; 78.8
# Nagaland_Lok_Sabha_constituency: Coordinates: 25.67; 94.12
# Jorhat_Lok_Sabha_constituency: Coordinates: 26.8; 94.2
# Ladakh_Lok_Sabha_constituency: Coordinates: 34.2; 77.6
# Haveri_Lok_Sabha_constituency: Coordinates: 14.80; 75.40
# Jalgaon_Lok_Sabha_constituency: Coordinates: 21.0; 75.6
# Barabanki_Lok_Sabha_constituency: Coordinates: 26.9; 81.2
# Palakkad_Lok_Sabha_constituency: Coordinates: 10.8; 76.7
# Chamarajanagar_Lok_Sabha_constituency: Coordinates: 11.9; 76.9
# Puducherry_Lok_Sabha_constituency: Coordinates: 11.93; 79.13
# Kakinada_Lok_Sabha_constituency: Coordinates: 16.98; 82.24
# Kanniyakumari_Lok_Sabha_constituency: Coordinates: 8.1; 77.5
# Vaishali_Lok_Sabha_constituency: Coordinates: 26.00; 85.08
# Dindigul_Lok_Sabha_constituency: Coordinates: 10.35; 77.95
# Madurai_Lok_Sabha_constituency: Coordinates: 9.9; 78.1
# Peddapalle_Lok_Sabha_constituency: Coordinates not found
# Durg_Lok_Sabha_constituency: Coordinates: 21.2; 81.3
# Gaya_Lok_Sabha_constituency: Coordinates: 24.80; 84.99
# Kushi_Nagar_Lok_Sabha_constituency: Coordinates: 26.9; 83.98
# Rajmahal_Lok_Sabha_constituency: Coordinates: 25.1; 87.8
# Ghaziabad_Lok_Sabha_constituency: Coordinates: 28.66; 77.45
# Ratnagiri_Sindhudurg_Lok_Sabha_constituency: Coordinates not found
# Shillong_Lok_Sabha_constituency: Coordinates: 25.6; 91.9
# Kaushambi_Lok_Sabha_constituency: Coordinates: 25.51; 81.43
# Tikamgarh_Lok_Sabha_constituency: Coordinates: 24.75; 78.80
# Ballia_Lok_Sabha_constituency: Coordinates: 25.76; 84.15
# Khajuraho_Lok_Sabha_constituency: Coordinates: 24.75; 80.16
# Palamu_Lok_Sabha_constituency: Coordinates: 23.8; 85.9
# Arani_Lok_Sabha_constituency: Coordinates: 12.67; 79.28
# Gwalior_Lok_Sabha_constituency: Coordinates: 26.22; 78.17
# Bellary_Lok_Sabha_constituency: Coordinates: 15.15; 76.91
# Kadapa_Lok_Sabha_constituency: Coordinates: 14.5; 78.8

# %%
df['coordinates'] = coord_list

# %%
df.head()
# Out:
#    Sno          Candidate     Constituency   Party  Criminal Case  \
# 0    1          A M Ariff        ALAPPUZHA  CPI(M)              2
# 1    2    A Narayanaswamy      CHITRADURGA     BJP              0
# 2    3            A. Raja         NILGIRIS     DMK              6
# 3    4     Abdul Khaleque          BARPETA     INC              0
# 4    5  Abhishek Banerjee  DIAMOND HARBOUR    AITC              0
#
#                Education               Total Assets              Liabilities  \
# 0  Graduate Professional  Rs 1,52,68,906 ~ 1 Crore+  Rs 22,20,700 ~ 22 Lacs+
# 1               Graduate  Rs 9,61,97,642 ~ 9 Crore+                   Rs 0 ~
# 2  Graduate Professional  Rs 4,95,91,024 ~ 4 Crore+  Rs 14,24,914 ~ 14 Lacs+
# 3          Post Graduate    Rs 73,98,753 ~ 73 Lacs+  Rs 27,03,693 ~ 27 Lacs+
# 4               Graduate  Rs 1,37,94,320 ~ 1 Crore+                   Rs 0 ~
#
#               coordinates
# 0             9.51; 76.34
# 1              14.2; 76.4
# 2              11.5; 76.6
# 3            26.32; 91.00
# 4  22.1910091; 88.1904741

# %%
df.isna().sum()
# Out:
# Sno               0
# Candidate         0
# Constituency      0
# Party             0
# Criminal Case     0
# Education         0
# Total Assets      0
# Liabilities       0
# coordinates      34
# dtype: int64

# %%
df.loc[df['coordinates'].isna()]
# Out:
#      Sno                         Candidate  \
# 35    36               Anurag Singh Thakur
# 37    38        Aparupa Poddar (Afrin Ali)
# 40    41                       Arjun Singh
# 49    50             Ashok Mahadevrao Nete
# 54    55                   B.N.Bache Gowda
# 73    74         Bhavana Pundlikrao Gawali
# 113  114        Delkar Mohanbhai Sanjibhai
# 118  119                   Dharambir Singh
# 124  125                      Dimple Yadav
# 148  149    Dr.Beesetti Venkata Satyavathi
# 155  156                          Dushyant
# 183  184                   Guharam Ajgalle
# 199  200                Imtiaz Jaleel Syed
# 206  207           Janardan Singh Sigriwal
# 223  224                  K. Muraleedharan
# 224  225                      K. Navaskani
# 227  228                   Kalyan Banerjee
# 231  232  Kanumuru Raghu Rama Krishna Raju
# 247  248                 Kodikunnil Suresh
# 254  255                Kuldeep Rai Sharma
# 259  260           Kunwar Pushpendra Singh
# 281  282              Manne Srinivas Reddy
# 283  284                     Manoj Rajoria
# 326  327                  Pankaj Choudhary
# 334  335           Patel Lalubhai Babubhai
# 345  346                  Pradyut Bordoloi
# 385  386                     Ram Shiromani
# 419  420               Renuka Singh Saruta
# 483  484          Sukhbir Singh Jaunapuria
# 487  488              Sunil Baburao Mendhe
# 495  496      Surendrajeet Singh Ahluwalia
# 499  500                Sushil Kumar Singh
# 525  526        Venkatesh Netha Borlakunta
# 531  532              Vinayak Bhaurao Raut
#
#                               Constituency  Party  Criminal Case  \
# 35                                HAMIRPUR    BJP              3
# 37                                 ARAMBAG   AITC              1
# 40                              BARRACKPUR    BJP             24
# 49                       GADCHIROLI CHIMUR    BJP              0
# 54                           CHIKKBALLAPUR    BJP              0
# 73                         YAVATMAL WASHIM    SHS              3
# 113                 DADRA AND NAGAR HAVELI    IND              0
# 118                   BHIWANI MAHENDRAGARH    BJP              0
# 124  MAINPURI : BYE ELECTION ON 05-12-2022     SP              0
# 148                             ANAKAPALLE  YSRCP              0
# 155                         JHALAWAR BARAN    BJP              0
# 183                         JANJGIR CHAMPA    BJP              0
# 199                             AURANGABAD  AIMIM              4
# 206                            MAHARAJGANJ    BJP              5
# 223                               VADAKARA    INC              3
# 224                         RAMANATHAPURAM   IUML              1
# 227                             SREERAMPUR   AITC              0
# 231                             NARSAPURAM  YSRCP              3
# 247                            MAVELIKKARA    INC              1
# 254            ANDAMAN AND NICOBAR ISLANDS    INC              0
# 259                               HAMIRPUR    BJP              4
# 281                            MAHBUBNAGAR    TRS              0
# 283                        KARAULI DHOLPUR    BJP              0
# 326                            MAHARAJGANJ    BJP              5
# 334                          DAMAN AND DIU    BJP              0
# 345                                NAWGONG    INC              0
# 385                              SHRAWASTI    BSP              0
# 419                                SURGUJA    BJP              0
# 483                    TONK SAWAI MADHOPUR    BJP              0
# 487                       BHANDARA GONDIYA    BJP              2
# 495                     BARDHAMAN DURGAPUR    BJP              0
# 499                             AURANGABAD    BJP              3
# 525                             PEDDAPALLE    TRS              0
# 531                   RATNAGIRI SINDHUDURG    SHS              3
#
#                  Education                    Total Assets  \
# 35                Graduate       Rs 5,67,70,463 ~ 5 Crore+
# 37           Post Graduate       Rs 1,25,27,597 ~ 1 Crore+
# 40               10th Pass         Rs 80,55,691 ~ 80 Lacs+
# 49               12th Pass       Rs 5,01,36,369 ~ 5 Crore+
# 54   Graduate Professional  Rs 1,15,35,01,141 ~ 115 Crore+
# 73                Graduate       Rs 9,68,73,189 ~ 9 Crore+
# 113               Graduate     Rs 70,88,85,980 ~ 70 Crore+
# 118               Graduate       Rs 6,06,42,205 ~ 6 Crore+
# 124               Graduate     Rs 39,91,50,143 ~ 39 Crore+
# 148  Graduate Professional       Rs 9,15,26,244 ~ 9 Crore+
# 155          Post Graduate     Rs 37,04,32,373 ~ 37 Crore+
# 183  Graduate Professional       Rs 1,84,00,837 ~ 1 Crore+
# 199          Post Graduate       Rs 2,95,62,768 ~ 2 Crore+
# 206               Graduate       Rs 1,04,51,986 ~ 1 Crore+
# 223               Graduate     Rs 11,43,79,340 ~ 11 Crore+
# 224              12th Pass     Rs 36,47,38,171 ~ 36 Crore+
# 227  Graduate Professional     Rs 17,59,68,902 ~ 17 Crore+
# 231          Post Graduate  Rs 3,25,94,05,378 ~ 325 Crore+
# 247  Graduate Professional       Rs 1,29,65,129 ~ 1 Crore+
# 254  Graduate Professional     Rs 13,22,33,012 ~ 13 Crore+
# 259          Post Graduate     Rs 16,71,59,924 ~ 16 Crore+
# 281              12th Pass       Rs 6,33,53,123 ~ 6 Crore+
# 283          Post Graduate       Rs 6,48,67,148 ~ 6 Crore+
# 326              12th Pass     Rs 37,18,27,109 ~ 37 Crore+
# 334               8th Pass     Rs 21,39,93,750 ~ 21 Crore+
# 345          Post Graduate       Rs 7,41,43,272 ~ 7 Crore+
# 385  Graduate Professional       Rs 1,91,08,216 ~ 1 Crore+
# 419              12th Pass       Rs 2,76,82,493 ~ 2 Crore+
# 483              12th Pass  Rs 1,23,38,02,420 ~ 123 Crore+
# 487                 Others     Rs 62,75,43,615 ~ 62 Crore+
# 495  Graduate Professional       Rs 2,65,21,750 ~ 2 Crore+
# 499          Post Graduate     Rs 16,78,95,109 ~ 16 Crore+
# 525              Doctorate       Rs 1,65,97,300 ~ 1 Crore+
# 531          Post Graduate       Rs 5,06,60,534 ~ 5 Crore+
#
#                         Liabilities coordinates
# 35          Rs 10,85,145 ~ 10 Lacs+        None
# 37          Rs 42,44,000 ~ 42 Lacs+        None
# 40          Rs 11,00,000 ~ 11 Lacs+        None
# 49        Rs 1,56,82,840 ~ 1 Crore+        None
# 54                           Rs 0 ~        None
# 73          Rs 73,96,250 ~ 73 Lacs+        None
# 113       Rs 3,72,68,162 ~ 3 Crore+        None
# 118           Rs 2,40,000 ~ 2 Lacs+        None
# 124         Rs 31,53,000 ~ 31 Lacs+        None
# 148       Rs 1,11,39,279 ~ 1 Crore+        None
# 155       Rs 8,58,24,156 ~ 8 Crore+        None
# 183                          Rs 0 ~        None
# 199         Rs 68,00,000 ~ 68 Lacs+        None
# 206           Rs 3,76,000 ~ 3 Lacs+        None
# 223                          Rs 0 ~        None
# 224       Rs 4,70,08,615 ~ 4 Crore+        None
# 227         Rs 55,22,403 ~ 55 Lacs+        None
# 231  Rs 1,01,44,67,354 ~ 101 Crore+        None
# 247           Rs 9,82,819 ~ 9 Lacs+        None
# 254       Rs 8,04,50,870 ~ 8 Crore+        None
# 259       Rs 3,55,02,582 ~ 3 Crore+        None
# 281         Rs 45,69,251 ~ 45 Lacs+        None
# 283       Rs 2,21,21,569 ~ 2 Crore+        None
# 326         Rs 44,83,048 ~ 44 Lacs+        None
# 334         Rs 99,69,514 ~ 99 Lacs+        None
# 345         Rs 40,11,152 ~ 40 Lacs+        None
# 385           Rs 3,50,000 ~ 3 Lacs+        None
# 419         Rs 32,51,275 ~ 32 Lacs+        None
# 483                          Rs 0 ~        None
# 487       Rs 1,98,61,338 ~ 1 Crore+        None
# 495           Rs 7,44,076 ~ 7 Lacs+        None
# 499         Rs 37,46,607 ~ 37 Lacs+        None
# 525                          Rs 0 ~        None
# 531         Rs 28,30,000 ~ 28 Lacs+        None

# %%
missing_constituency = df.loc[df.coordinates.isna(), ['Constituency', 'Candidate']]
missing_constituency
# Out:
#                               Constituency                         Candidate
# 35                                HAMIRPUR               Anurag Singh Thakur
# 37                                 ARAMBAG        Aparupa Poddar (Afrin Ali)
# 40                              BARRACKPUR                       Arjun Singh
# 49                       GADCHIROLI CHIMUR             Ashok Mahadevrao Nete
# 54                           CHIKKBALLAPUR                   B.N.Bache Gowda
# 73                         YAVATMAL WASHIM         Bhavana Pundlikrao Gawali
# 113                 DADRA AND NAGAR HAVELI        Delkar Mohanbhai Sanjibhai
# 118                   BHIWANI MAHENDRAGARH                   Dharambir Singh
# 124  MAINPURI : BYE ELECTION ON 05-12-2022                      Dimple Yadav
# 148                             ANAKAPALLE    Dr.Beesetti Venkata Satyavathi
# 155                         JHALAWAR BARAN                          Dushyant
# 183                         JANJGIR CHAMPA                   Guharam Ajgalle
# 199                             AURANGABAD                Imtiaz Jaleel Syed
# 206                            MAHARAJGANJ           Janardan Singh Sigriwal
# 223                               VADAKARA                  K. Muraleedharan
# 224                         RAMANATHAPURAM                      K. Navaskani
# 227                             SREERAMPUR                   Kalyan Banerjee
# 231                             NARSAPURAM  Kanumuru Raghu Rama Krishna Raju
# 247                            MAVELIKKARA                 Kodikunnil Suresh
# 254            ANDAMAN AND NICOBAR ISLANDS                Kuldeep Rai Sharma
# 259                               HAMIRPUR           Kunwar Pushpendra Singh
# 281                            MAHBUBNAGAR              Manne Srinivas Reddy
# 283                        KARAULI DHOLPUR                     Manoj Rajoria
# 326                            MAHARAJGANJ                  Pankaj Choudhary
# 334                          DAMAN AND DIU           Patel Lalubhai Babubhai
# 345                                NAWGONG                  Pradyut Bordoloi
# 385                              SHRAWASTI                     Ram Shiromani
# 419                                SURGUJA               Renuka Singh Saruta
# 483                    TONK SAWAI MADHOPUR          Sukhbir Singh Jaunapuria
# 487                       BHANDARA GONDIYA              Sunil Baburao Mendhe
# 495                     BARDHAMAN DURGAPUR      Surendrajeet Singh Ahluwalia
# 499                             AURANGABAD                Sushil Kumar Singh
# 525                             PEDDAPALLE        Venkatesh Netha Borlakunta
# 531                   RATNAGIRI SINDHUDURG              Vinayak Bhaurao Raut

# %% [markdown]
# The above constituency coordinates could not be found as wiki page with the provided expression could not be found. On further checking it was found that these constituencies have inconsistent wiki page urls. example:
#
# https://en.wikipedia.org/wiki/Hamirpur,_Himachal_Pradesh_Lok_Sabha_constituency,
# https://en.wikipedia.org/wiki/Hamirpur,_Uttar_Pradesh_Lok_Sabha_constituency
#
# Wikipedia page search API and matching with candidate name was also tried and could not provide reliable results, as name of candidates is not similar in wikipedia and the data scraped from myneta info.
# Hence for these manually values are collected.

# %%
missing_coordinates = ['31.7; 76.5',
'22.9; 87.8',
'22.76; 88.37',
'20.3; 79.7',
'13.4; 77.7',
'20.3; 77.6',
'20.27; 73.02',
'28.5; 76.1',
'79.03',
'17.69; 83.00',
'24.8; 76.4',
'22.0; 82.6',
'19.8887861; 75.3434361',
'26.1; 84.5',
'11.6; 75.6',
'11.0; 77.0',
'22.7500; 88.3400',
'16.4; 81.7',
'9.24; 76.54',
'10; 93',
'25.95; 80.15',
'16.7; 78.0',
'26.6; 77.5',
'27.15; 83.56',
'20.42; 72.83',
'26.35; 92.69',
'27.7; 81.84',
'23.1; 83.2',
'26.0; 76.0',
'21.3; 79.9',
'23.4; 87.6',
'24.8; 84.4',
'18.6; 79.4',
'16.7; 73.4']

# %%
print(len(missing_coordinates), len(df.loc[df['coordinates'].isna()]))
# Out:
# 34 34

# %% [markdown]
# Filling the missing coordinates

# %%
df.loc[df['coordinates'].isna(), 'coordinates'] = (missing_coordinates)

# %%
df.isna().sum()
# Out:
# Sno              0
# Candidate        0
# Constituency     0
# Party            0
# Criminal Case    0
# Education        0
# Total Assets     0
# Liabilities      0
# coordinates      0
# dtype: int64

# %%
df.coordinates
# Out:
# 0                 9.51; 76.34
# 1                  14.2; 76.4
# 2                  11.5; 76.6
# 3                26.32; 91.00
# 4      22.1910091; 88.1904741
#                 ...
# 537                23.8; 85.9
# 538              12.67; 79.28
# 539              26.22; 78.17
# 540              15.15; 76.91
# 541                14.5; 78.8
# Name: coordinates, Length: 542, dtype: object

# %% [markdown]
# Extracting latitude and longitude values in seperate columns.

# %%
df['lat']=df.coordinates.apply(lambda x : float((x.split(';')[0])))
df['lng']=df.coordinates.apply(lambda x : float((x.split(';')[-1])))

# %% [markdown]
# Assests value converted to float for easy plotting.

# %%
df['Total Assets'] =df['Total Assets'].apply(lambda x: float(x[2:].split('~')[0].replace(",","")))
df['Liabilities'] =df['Liabilities'].apply(lambda x: float(x[2:].split('~')[0].replace(",","")))

# %%
df.rename(columns={'Total Assets': 'Total Assets in Rupees'}, inplace = True)
df.rename(columns={'Liabilities': 'Liabilities in Rupees'}, inplace = True)

# %%
df.head()
# Out:
#    Sno          Candidate     Constituency   Party  Criminal Case  \
# 0    1          A M Ariff        ALAPPUZHA  CPI(M)              2
# 1    2    A Narayanaswamy      CHITRADURGA     BJP              0
# 2    3            A. Raja         NILGIRIS     DMK              6
# 3    4     Abdul Khaleque          BARPETA     INC              0
# 4    5  Abhishek Banerjee  DIAMOND HARBOUR    AITC              0
#
#                Education  Total Assets in Rupees  Liabilities in Rupees  \
# 0  Graduate Professional              15268906.0              2220700.0
# 1               Graduate              96197642.0                    0.0
# 2  Graduate Professional              49591024.0              1424914.0
# 3          Post Graduate               7398753.0              2703693.0
# 4               Graduate              13794320.0                    0.0
#
#               coordinates        lat        lng
# 0             9.51; 76.34   9.510000  76.340000
# 1              14.2; 76.4  14.200000  76.400000
# 2              11.5; 76.6  11.500000  76.600000
# 3            26.32; 91.00  26.320000  91.000000
# 4  22.1910091; 88.1904741  22.191009  88.190474

# %%
df.to_csv(path_or_buf='lok_sabha_winners_with_geocode.csv', index=False)

# %% [markdown]
# ### Now plot the dataframe on the map using pydeck.

# %%
"""
ScatterplotLayer
================

Plot of the number of exits for various subway stops within San Francisco, California.

Adapted from the deck.gl documentation.
"""
import pydeck as pdk
import pandas as pd
import math
from pydeck.types import String
import random

def scatter_plot(df):
    # Use pandas to calculate additional data
    df["assets_radius"] = df["Total Assets in Rupees"].apply(
        lambda exits_count: math.sqrt(exits_count)
    )
    # print(df)
    random.seed(23)
    color_lookup = pdk.data_utils.assign_random_colors(df['Party'])
    # Assign a color based on Party
    df['color'] = df.apply(lambda row: color_lookup.get(row['Party']), axis=1)
    # # Define a layer to display on a map
    layer = pdk.Layer(
        "ScatterplotLayer",
        df,
        pickable=True,
        opacity=0.4,
        stroked=True,
        filled=True,
        radius_scale=2,
        radius_min_pixels=1,
        radius_max_pixels=100,
        line_width_min_pixels=1,
        get_position=["lng", "lat"],
        get_radius="assets_radius",
        get_fill_color= "color", #"[Party == 'BJP' ? 255 : 0, 0, Party == 'BJP' ? 0 : 255]",
        get_line_color=[0, 0, 0],
    )

    # # Set the viewport location
    view_state = pdk.ViewState(
        latitude=20, longitude=80, zoom=3, bearing=0, pitch=0
    )

    # # Render
    r = pdk.Deck(
        layers=[layer],
        initial_view_state=view_state,
        tooltip={
            "text": "{Party}\n{Constituency}\n{Candidate}\nTotal Assets: Rs. {Total Assets in Rupees}"
        },
    )
    r.to_html("scatterplot_layer.html")
    return r

# %%
df = pd.read_csv("lok_sabha_winners_with_geocode.csv")
deck_object = scatter_plot(df)
deck_object.show()
# Out:
# DeckGLWidget(carto_key=None, custom_libraries=[], google_maps_key=None, json_input='{\n  "initialViewState": {…
